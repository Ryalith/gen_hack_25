# %%
from pathlib import Path
from src import set_main_data_folder, eca, ndvi

# %%
set_main_data_folder(Path('/ssd2/mldata/GenHack2025/data'))
# Out:
# /ssd2/mldata/GenHack2025/data

# %% [markdown]
# # Goals
#
# Establish joint dataset with data from ECA - NDVI - ERA5
#
# Establish correlation between NDVI and the temperature delta between ERA5 and ECA
#
# ## First Steps
#
# Plotting for a single period

# %%
year = 2020
quarter = 1

# %%
ndvi_raster = ndvi.from_timeperiod(year, quarter)
# Out:
# [[[255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   ...
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]]]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ndvi_raster = ndvi.from_timeperiod(year, quarter)
#
# File ~/Partage_VM/MS2A/GenHack2025/gen_hack_25/src/ndvi.py:11, in from_timeperiod(year, quarter)
#       8 filepath = get_main_data_folder() / "sentinel2_ndvi" / f"ndvi_{timeperiod}.tif"
#      10 with rasterio.open(filepath) as src:
# ---> 11     output_raster = convert_ndvi_to_real_scale(src.read(), src.meta)
#      13 return output_raster
#
# File ~/Partage_VM/MS2A/GenHack2025/gen_hack_25/src/utils.py:30, in convert_ndvi_to_real_scale(ndvi_img, out_meta)
#      26 def convert_ndvi_to_real_scale(ndvi_img, out_meta):
# ...

# %%
eca_df = eca.from_timeperiod(year, quarter)
