# %%
from src import gh25

# %%
gh25_gdf = gh25.from_timeperiod_variable(2020, 1, "2m_temperature")
# Out:
# No data for year=2020, quarter=1, variable='2m_temperature', building GeoDataframe ...
# Found data for year=2020, quarter=1, loading Dataframe ...

# %%
gh25_gdf
# Out:
#         Unnamed: 0  STAID  SOUID        DATE   TX  Q_TX  TX_kelvin  \
# 0                0      2  36438  2020-01-01   54     0     278.55
# 1                1      2  36438  2020-01-02   63     0     279.45
# 2                2      2  36438  2020-01-03   68     0     279.95
# 3                3      2  36438  2020-01-04   27     0     275.85
# 4                4      2  36438  2020-01-05    9     0     274.05
# ...            ...    ...    ...         ...  ...   ...        ...
# 466833      466833  28077  98794  2020-03-27   86     0     281.75
# 466834      466834  28077  98794  2020-03-28   83     0     281.45
# 466835      466835  28077  98794  2020-03-29   65     0     279.65
# 466836      466836  28077  98794  2020-03-30   58     0     278.95
# 466837      466837  28077  98794  2020-03-31  132     0     286.35
#
#         LON_decimal  LAT_decimal         t2m                   geometry
# 0         15.616667    60.616667  276.262390  POINT (15.61667 60.61667)
# ...
